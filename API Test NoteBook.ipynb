# %%
  
 #This example uses Python 2.7 and the python-request library.
    #Increase the Data Rate Limit:  "jupyter notebook --NotebookApp.iopub_data_rate_limit=10000000"

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '64f2516a-cdcc-4de7-8a10-b1e83edb39d8',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             11631
# 1    1027      Ethereum    ETH      ethereum              9202
# 2     825   Tether USDt   USDT        tether             93852
# 3    1839           BNB    BNB           bnb              2206
# 4    5426        Solana    SOL        solana               714
# 5    3408          USDC   USDC      usd-coin             21447
# 6      52           XRP    XRP           xrp              1363
# 7   11419       Toncoin    TON       toncoin               499
# 8      74      Dogecoin   DOGE      dogecoin              1034
# 9    2010       Cardano    ADA       cardano              1221
# 10   1958          TRON    TRX          tron              1006
# 11   5805     Avalanche   AVAX     avalanche               761
# 12   5994     Shiba Inu   SHIB     shiba-inu               854
# 13   6636      Polkadot    DOT  polkadot-new               798
# 14   1831  Bitcoin Cash    BCH  bitcoin-cash               909
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2021-08-26T13:40:22.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2017-10-01T00:00:00.000Z
# 10  2017-09-13T00:00:00.000Z
# 11  2020-07-13T00:00:00.000Z
# 12  2020-08-01T00:00:00.000Z
# 13  2020-08-19T00:00:00.000Z
# 14  2017-07-23T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [stablecoin, asset-backed-stablecoin, avalanch...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 7   [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...           NaN
# 8   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 9   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 10  [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 11  [defi, smart-contracts, three-arrows-capital-p...  7.157487e+08
# 12      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 13  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 14  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.973752e+07  1.973752e+07            False       NaN         1
# 1         1.202632e+08  1.202632e+08             True       NaN         2
# 2         1.154047e+11  1.170681e+11             True       NaN         3
# 3         1.459367e+08  1.459367e+08            False       NaN         4
# 4         4.663386e+08  5.817957e+08             True       NaN         5
# 5         3.445187e+10  3.445187e+10            False       NaN         6
# 6         5.610436e+10  9.998737e+10            False       NaN         7
# 7         2.518346e+09  5.110221e+09             True       NaN         8
# 8         1.454609e+11  1.454609e+11             True       NaN         9
# 9         3.592559e+10  3.711661e+10            False       NaN        10
# 10        8.699402e+10  8.699405e+10             True       NaN        11
# 11        3.950933e+08  4.444396e+08            False       NaN        12
# 12        5.892704e+14  5.895191e+14            False       NaN        13
# 13        1.478810e+09  1.478810e+09             True       NaN        14
# 14        1.974446e+07  1.974446e+07            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                       3.414167e+09              2.210884e+10      None
# 8                                NaN                       NaN      None
# 9                                NaN                       NaN      None
# 10                      7.165966e+10              9.084081e+09      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                      1.478810e+09              7.050846e+09      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2024-08-09T10:27:00.000Z     60437.083574          4.358714e+10
# 1   2024-08-09T10:26:00.000Z      2632.400696          2.299655e+10
# 2   2024-08-09T10:26:00.000Z         1.000341          7.043640e+10
# 3   2024-08-09T10:26:00.000Z       503.937379          1.735552e+09
# 4   2024-08-09T10:26:00.000Z       156.169360          4.612387e+09
# 5   2024-08-09T10:26:00.000Z         1.000096          8.094246e+09
# 6   2024-08-09T10:27:00.000Z         0.586901          2.698282e+09
# 7   2024-08-09T10:26:00.000Z         6.475619          8.533865e+08
# 8   2024-08-09T10:27:00.000Z         0.104053          7.933070e+08
# 9   2024-08-09T10:26:00.000Z         0.342022          3.250132e+08
# 10  2024-08-09T10:26:00.000Z         0.126767          2.905682e+08
# 11  2024-08-09T10:26:00.000Z        21.569193          3.143683e+08
# 12  2024-08-09T10:26:00.000Z         0.000014          3.031306e+08
# 13  2024-08-09T10:26:00.000Z         4.767919          1.678799e+08
# 14  2024-08-09T10:26:00.000Z       343.009963          4.106881e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                        9.6677                    -0.919780
# 1                       -0.9224                    -1.273405
# 2                        0.9090                     0.014503
# 3                       -3.4671                    -0.921704
# 4                      -12.7777                    -1.309358
# 5                       -4.8853                     0.011972
# 6                      -50.4460                    -1.609578
# 7                        2.6318                    -0.131809
# 8                      -15.2546                    -1.165902
# 9                       -3.6505                    -1.151273
# 10                      -5.5003                    -0.244492
# 11                      18.3192                    -1.170438
# 12                       2.1586                    -1.529138
# 13                     -13.7654                    -0.785073
# 14                      47.4567                    -1.238475
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       4.977760                    -6.327392
# 1                       8.065126                   -16.431997
# 2                       0.005621                     0.119961
# 3                       3.080758                   -11.729815
# 4                       1.522969                    -4.819402
# 5                       0.007838                     0.020048
# 6                      -4.543390                     2.114632
# 7                       5.972111                    -1.719714
# 8                       4.085333                   -11.050581
# 9                       2.496319                   -10.806591
# 10                      0.677175                    -0.320664
# 11                      4.874517                   -13.778279
# 12                      4.541408                   -10.116133
# 13                      1.978060                    -9.123769
# 14                      5.867005                   -15.291992
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       3.185647                    -12.857635
# 1                     -14.894135                    -28.316341
# 2                       0.036127                      0.039659
# 3                      -3.952895                    -21.874369
# 4                       8.822262                     -2.271190
# 5                       0.013940                     -0.016679
# 6                      32.912920                     18.456565
# 7                     -11.675024                     -8.458458
# 8                      -4.325503                    -28.388612
# 9                     -11.079638                    -23.947474
# 10                     -2.604311                      8.988800
# 11                    -19.725019                    -34.245223
# 12                    -16.269110                    -40.193843
# 13                    -22.456150                    -26.715133
# 14                      0.668102                    -26.420039
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      -0.678744          1.192878e+12
# 1                      -9.454349          3.165809e+11
# 2                       0.067551          1.154440e+11
# 3                     -14.116991          7.354295e+10
# 4                       7.971656          7.282780e+10
# 5                       0.008972          3.445517e+10
# 6                      16.627810          3.292769e+10
# 7                      -3.182616          1.630785e+10
# 8                     -27.587114          1.513563e+10
# 9                     -23.080042          1.228736e+10
# 10                     -0.056273          1.102797e+10
# 11                    -35.563749          8.521843e+09
# 12                    -38.351782          8.199397e+09
# 13                    -28.683794          7.050846e+09
# 14                    -19.968715          6.772546e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          56.5161                        1.269179e+12
# 1                          14.9603                        3.165809e+11
# 2                           5.4358                        1.171080e+11
# 3                           3.4628                        7.354295e+10
# 4                           3.4415                        9.085867e+10
# 5                           1.6324                        3.445517e+10
# 6                           1.5577                        5.869007e+10
# 7                           0.7726                        3.309184e+10
# 8                           0.7171                        1.513563e+10
# 9                           0.5821                        1.539101e+10
# 10                          0.5225                        1.102798e+10
# 11                          0.4037                        1.543812e+10
# 12                          0.3885                        8.202857e+09
# 13                          0.3341                        7.050846e+09
# 14                          0.3189                        7.203209e+09
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2024-08-09T10:27:00.000Z          NaN           NaN
# 1           None  2024-08-09T10:26:00.000Z          NaN           NaN
# 2           None  2024-08-09T10:26:00.000Z       1027.0      Ethereum
# 3           None  2024-08-09T10:26:00.000Z          NaN           NaN
# 4           None  2024-08-09T10:26:00.000Z          NaN           NaN
# 5           None  2024-08-09T10:26:00.000Z       1027.0      Ethereum
# 6           None  2024-08-09T10:27:00.000Z          NaN           NaN
# 7           None  2024-08-09T10:26:00.000Z          NaN           NaN
# 8           None  2024-08-09T10:27:00.000Z          NaN           NaN
# 9           None  2024-08-09T10:26:00.000Z          NaN           NaN
# 10          None  2024-08-09T10:26:00.000Z          NaN           NaN
# 11          None  2024-08-09T10:26:00.000Z          NaN           NaN
# 12          None  2024-08-09T10:26:00.000Z       1027.0      Ethereum
# 13          None  2024-08-09T10:26:00.000Z          NaN           NaN
# 14          None  2024-08-09T10:26:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 13             NaN           NaN                                         NaN
# 14             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2024-08-09 11:28:33.139670
# 1  2024-08-09 11:28:33.139670
# 2  2024-08-09 11:28:33.139670
# 3  2024-08-09 11:28:33.139670
# 4  2024-08-09 11:28:33.139670
# 5  2024-08-09 11:28:33.139670
# 6  2024-08-09 11:28:33.139670
# 7  2024-08-09 11:28:33.139670
# 8  2024-08-09 11:28:33.139670
# 9  2024-08-09 11:28:33.139670
# 10 2024-08-09 11:28:33.139670
# 11 2024-08-09 11:28:33.139670
# 12 2024-08-09 11:28:33.139670
# 13 2024-08-09 11:28:33.139670
# 14 2024-08-09 11:28:33.139670

# %%
import pandas as pd
from time import sleep
import json
from requests import Session, ConnectionError, Timeout, TooManyRedirects

# Initialize an empty DataFrame to store all the data
df = pd.DataFrame()

def api_runner():
    global df  # Declare df as global so it can be updated within the function
    
    # Your existing code for API calls and processing data
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
        'start': '1',
        'limit': '15',
        'convert': 'USD'
    }
    headers = {
        'Accepts': 'application/json',
        'X-CMC_PRO_API_KEY': '64f2516a-cdcc-4de7-8a10-b1e83edb39d8',
    }

    session = Session()
    session.headers.update(headers)

    try:
        response = session.get(url, params=parameters)
        data = json.loads(response.text)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
        print(e)
        return  # Exit the function if there's an error

    # Assuming 'data' is your JSON response:
    df2 = pd.json_normalize(data['data'])
    df2['timestamp'] = pd.to_datetime('now')
    df = pd.concat([df, df2], ignore_index=True)

    if not os.path.isfile(r'C:\Users\10agn\OneDrive\Documents\Python Scripts\API.csv'):
        df.to_csv(r'C:\Users\10agn\OneDrive\Documents\Python Scripts\API.csv', header= column_names)
    else:
        df.to_csv(r'C:\Users\10agn\OneDrive\Documents\Python Scripts\API.csv', mode= 'a', header=False)

for i in range(333):
    api_runner()
    print('API Runner completed successfully')
    sleep(60)
# Out:
# API Runner completed successfully
# API Runner completed successfully
# API Runner completed successfully
# API Runner completed successfully
# API Runner completed successfully
# API Runner completed successfully
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 44
#      42 api_runner()
#      43 print('API Runner completed successfully')
# ---> 44 sleep(60)
#
# KeyboardInterrupt:

# %%
df20 = pd.read_csv(r'C:\Users\10agn\OneDrive\Documents\Python Scripts\API.csv')
df20

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             11631
# 1    1027      Ethereum    ETH      ethereum              9202
# 2     825   Tether USDt   USDT        tether             93852
# 3    1839           BNB    BNB           bnb              2206
# 4    5426        Solana    SOL        solana               714
# 5    3408          USDC   USDC      usd-coin             21447
# 6      52           XRP    XRP           xrp              1363
# 7   11419       Toncoin    TON       toncoin               499
# 8      74      Dogecoin   DOGE      dogecoin              1034
# 9    2010       Cardano    ADA       cardano              1221
# 10   1958          TRON    TRX          tron              1006
# 11   5805     Avalanche   AVAX     avalanche               761
# 12   5994     Shiba Inu   SHIB     shiba-inu               854
# 13   6636      Polkadot    DOT  polkadot-new               798
# 14   1831  Bitcoin Cash    BCH  bitcoin-cash               909
# 15      1       Bitcoin    BTC       bitcoin             11631
# 16   1027      Ethereum    ETH      ethereum              9202
# 17    825   Tether USDt   USDT        tether             93852
# 18   1839           BNB    BNB           bnb              2206
# 19   5426        Solana    SOL        solana               714
# 20   3408          USDC   USDC      usd-coin             21447
# 21     52           XRP    XRP           xrp              1363
# 22  11419       Toncoin    TON       toncoin               499
# 23     74      Dogecoin   DOGE      dogecoin              1034
# 24   2010       Cardano    ADA       cardano              1221
# 25   1958          TRON    TRX          tron              1006
# 26   5805     Avalanche   AVAX     avalanche               761
# 27   5994     Shiba Inu   SHIB     shiba-inu               854
# 28   6636      Polkadot    DOT  polkadot-new               798
# 29   1831  Bitcoin Cash    BCH  bitcoin-cash               909
# 30      1       Bitcoin    BTC       bitcoin             11631
# 31   1027      Ethereum    ETH      ethereum              9202
# 32    825   Tether USDt   USDT        tether             93852
# 33   1839           BNB    BNB           bnb              2206
# 34   5426        Solana    SOL        solana               714
# 35   3408          USDC   USDC      usd-coin             21447
# 36     52           XRP    XRP           xrp              1363
# 37  11419       Toncoin    TON       toncoin               499
# 38     74      Dogecoin   DOGE      dogecoin              1034
# 39   2010       Cardano    ADA       cardano              1221
# 40   1958          TRON    TRX          tron              1006
# 41   5805     Avalanche   AVAX     avalanche               761
# 42   5994     Shiba Inu   SHIB     shiba-inu               854
# 43   6636      Polkadot    DOT  polkadot-new               798
# 44   1831  Bitcoin Cash    BCH  bitcoin-cash               909
# 45      1       Bitcoin    BTC       bitcoin             11631
# 46   1027      Ethereum    ETH      ethereum              9202
# 47    825   Tether USDt   USDT        tether             93852
# 48   1839           BNB    BNB           bnb              2206
# 49   5426        Solana    SOL        solana               714
# 50   3408          USDC   USDC      usd-coin             21447
# 51     52           XRP    XRP           xrp              1363
# 52  11419       Toncoin    TON       toncoin               499
# 53     74      Dogecoin   DOGE      dogecoin              1034
# 54   2010       Cardano    ADA       cardano              1221
# 55   1958          TRON    TRX          tron              1006
# 56   5805     Avalanche   AVAX     avalanche               761
# 57   5994     Shiba Inu   SHIB     shiba-inu               854
# 58   6636      Polkadot    DOT  polkadot-new               798
# 59   1831  Bitcoin Cash    BCH  bitcoin-cash               909
# 60      1       Bitcoin    BTC       bitcoin             11631
# 61   1027      Ethereum    ETH      ethereum              9202
# 62    825   Tether USDt   USDT        tether             93852
# 63   1839           BNB    BNB           bnb              2206
# 64   5426        Solana    SOL        solana               714
# 65   3408          USDC   USDC      usd-coin             21447
# 66     52           XRP    XRP           xrp              1363
# 67  11419       Toncoin    TON       toncoin               499
# 68     74      Dogecoin   DOGE      dogecoin              1034
# 69   2010       Cardano    ADA       cardano              1221
# 70   1958          TRON    TRX          tron              1006
# 71   5805     Avalanche   AVAX     avalanche               761
# 72   5994     Shiba Inu   SHIB     shiba-inu               854
# 73   6636      Polkadot    DOT  polkadot-new               798
# 74   1831  Bitcoin Cash    BCH  bitcoin-cash               909
# 75      1       Bitcoin    BTC       bitcoin             11631
# 76   1027      Ethereum    ETH      ethereum              9202
# 77    825   Tether USDt   USDT        tether             93852
# 78   1839           BNB    BNB           bnb              2206
# 79   5426        Solana    SOL        solana               714
# 80   3408          USDC   USDC      usd-coin             21447
# 81     52           XRP    XRP           xrp              1363
# 82  11419       Toncoin    TON       toncoin               499
# 83     74      Dogecoin   DOGE      dogecoin              1034
# 84   2010       Cardano    ADA       cardano              1221
# 85   1958          TRON    TRX          tron              1006
# 86   5805     Avalanche   AVAX     avalanche               761
# 87   5994     Shiba Inu   SHIB     shiba-inu               854
# 88   6636      Polkadot    DOT  polkadot-new               798
# 89   1831  Bitcoin Cash    BCH  bitcoin-cash               909
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2021-08-26T13:40:22.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2017-10-01T00:00:00.000Z
# 10  2017-09-13T00:00:00.000Z
# 11  2020-07-13T00:00:00.000Z
# 12  2020-08-01T00:00:00.000Z
# 13  2020-08-19T00:00:00.000Z
# 14  2017-07-23T00:00:00.000Z
# 15  2010-07-13T00:00:00.000Z
# 16  2015-08-07T00:00:00.000Z
# 17  2015-02-25T00:00:00.000Z
# 18  2017-07-25T00:00:00.000Z
# 19  2020-04-10T00:00:00.000Z
# 20  2018-10-08T00:00:00.000Z
# 21  2013-08-04T00:00:00.000Z
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 2   [stablecoin, asset-backed-stablecoin, avalanch...                NaN
# 3   [marketplace, centralized-exchange, payments, ...                NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 6   [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 7   [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...                NaN
# 8   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 9   [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 10  [media, payments, tron-ecosystem, layer-1, dwf...                NaN
# 11  [defi, smart-contracts, three-arrows-capital-p...    715748719.00000
# 12      [memes, ethereum-ecosystem, doggone-doggerel]                NaN
# 13  [substrate, polkadot, binance-chain, polkadot-...                NaN
# 14  [mineable, pow, sha-256, marketplace, medium-o...     21000000.00000
# 15  [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 16  [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 17  [stablecoin, asset-backed-stablecoin, avalanch...                NaN
# 18  [marketplace, centralized-exchange, payments, ...                NaN
# 19  [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 20  [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 21  [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 22  [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...                NaN
# 23  [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 24  [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 25  [media, payments, tron-ecosystem, layer-1, dwf...                NaN
# 26  [defi, smart-contracts, three-arrows-capital-p...    715748719.00000
# 27      [memes, ethereum-ecosystem, doggone-doggerel]                NaN
# 28  [substrate, polkadot, binance-chain, polkadot-...                NaN
# 29  [mineable, pow, sha-256, marketplace, medium-o...     21000000.00000
# 30  [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 31  [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 32  [stablecoin, asset-backed-stablecoin, avalanch...                NaN
# 33  [marketplace, centralized-exchange, payments, ...                NaN
# 34  [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 35  [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 36  [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 37  [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...                NaN
# 38  [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 39  [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 40  [media, payments, tron-ecosystem, layer-1, dwf...                NaN
# 41  [defi, smart-contracts, three-arrows-capital-p...    715748719.00000
# 42      [memes, ethereum-ecosystem, doggone-doggerel]                NaN
# 43  [substrate, polkadot, binance-chain, polkadot-...                NaN
# 44  [mineable, pow, sha-256, marketplace, medium-o...     21000000.00000
# 45  [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 46  [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 47  [stablecoin, asset-backed-stablecoin, avalanch...                NaN
# 48  [marketplace, centralized-exchange, payments, ...                NaN
# 49  [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 50  [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 51  [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 52  [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...                NaN
# 53  [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 54  [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 55  [media, payments, tron-ecosystem, layer-1, dwf...                NaN
# 56  [defi, smart-contracts, three-arrows-capital-p...    715748719.00000
# 57      [memes, ethereum-ecosystem, doggone-doggerel]                NaN
# 58  [substrate, polkadot, binance-chain, polkadot-...                NaN
# 59  [mineable, pow, sha-256, marketplace, medium-o...     21000000.00000
# 60  [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 61  [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 62  [stablecoin, asset-backed-stablecoin, avalanch...                NaN
# 63  [marketplace, centralized-exchange, payments, ...                NaN
# 64  [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 65  [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 66  [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 67  [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...                NaN
# 68  [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 69  [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 70  [media, payments, tron-ecosystem, layer-1, dwf...                NaN
# 71  [defi, smart-contracts, three-arrows-capital-p...    715748719.00000
# 72      [memes, ethereum-ecosystem, doggone-doggerel]                NaN
# 73  [substrate, polkadot, binance-chain, polkadot-...                NaN
# 74  [mineable, pow, sha-256, marketplace, medium-o...     21000000.00000
# 75  [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 76  [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 77  [stablecoin, asset-backed-stablecoin, avalanch...                NaN
# 78  [marketplace, centralized-exchange, payments, ...                NaN
# 79  [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 80  [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 81  [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 82  [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...                NaN
# 83  [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 84  [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 85  [media, payments, tron-ecosystem, layer-1, dwf...                NaN
# 86  [defi, smart-contracts, three-arrows-capital-p...    715748719.00000
# 87      [memes, ethereum-ecosystem, doggone-doggerel]                NaN
# 88  [substrate, polkadot, binance-chain, polkadot-...                NaN
# 89  [mineable, pow, sha-256, marketplace, medium-o...     21000000.00000
#
#       circulating_supply          total_supply  infinite_supply  platform  \
# 0         19737525.00000        19737525.00000            False       NaN
# 1        120263205.46332       120263205.46332             True       NaN
# 2     115404652458.26874    117068077122.62410             True       NaN
# 3        145936690.19718       145936690.19718            False       NaN
# 4        466338618.33670       581795745.95608             True       NaN
# 5      34451865814.29645     34451865814.29645            False       NaN
# 6      56104361423.00000     99987365591.00000            False       NaN
# 7       2518346354.11617      5110221387.05400             True       NaN
# 8     145460946383.70520    145460946383.70520             True       NaN
# 9      35925585064.08800     37116609473.74700            False       NaN
# 10     86994020027.54974     86994053860.13481             True       NaN
# 11       395093253.31204       444439623.31204            False       NaN
# 12 589270406494833.50000 589519077523462.00000            False       NaN
# 13      1478809897.43149      1478809897.43149             True       NaN
# 14        19744459.37500        19744459.37500            False       NaN
# 15        19737525.00000        19737525.00000            False       NaN
# 16       120263205.46332       120263205.46332             True       NaN
# 17    115404652458.26874    117068077122.62410             True       NaN
# 18       145936690.19718       145936690.19718            False       NaN
# 19       466338618.33670       581795745.95608             True       NaN
# 20     34451865814.29645     34451865814.29645            False       NaN
# 21     56104361423.00000     99987365591.00000            False       NaN
# 22      2518346354.11617      5110221387.05400             True       NaN
# 23    145460946383.70520    145460946383.70520             True       NaN
# 24     35925585064.08800     37116609473.74700            False       NaN
# 25     86994020027.54974     86994053860.13481             True       NaN
# 26       395093253.31204       444439623.31204            False       NaN
# 27 589270406494833.50000 589519077523462.00000            False       NaN
# 28      1478809897.43149      1478809897.43149             True       NaN
# 29        19744459.37500        19744459.37500            False       NaN
# 30        19737525.00000        19737525.00000            False       NaN
# 31       120263205.46332       120263205.46332             True       NaN
# 32    115404652458.26874    117068077122.62410             True       NaN
# 33       145936690.19718       145936690.19718            False       NaN
# 34       466338618.33670       581795745.95608             True       NaN
# 35     34451865814.29645     34451865814.29645            False       NaN
# 36     56104361423.00000     99987365591.00000            False       NaN
# 37      2518346354.11617      5110221387.05400             True       NaN
# 38    145460946383.70520    145460946383.70520             True       NaN
# 39     35925585064.08800     37116609473.74700            False       NaN
# 40     86994020027.54974     86994053860.13481             True       NaN
# 41       395093253.31204       444439623.31204            False       NaN
# 42 589270406494833.50000 589519077523462.00000            False       NaN
# 43      1478809897.43149      1478809897.43149             True       NaN
# 44        19744459.37500        19744459.37500            False       NaN
# 45        19737525.00000        19737525.00000            False       NaN
# 46       120263205.46332       120263205.46332             True       NaN
# 47    115404652458.26874    117068077122.62410             True       NaN
# 48       145936690.19718       145936690.19718            False       NaN
# 49       466338618.33670       581795745.95608             True       NaN
# 50     34440578403.00486     34440578403.00486            False       NaN
# 51     56104361423.00000     99987365591.00000            False       NaN
# 52      2518346354.11617      5110221387.05400             True       NaN
# 53    145461176383.70526    145461176383.70526             True       NaN
# 54     35925585512.10200     37116609473.74700            False       NaN
# 55     86993835819.56819     86993913900.11557             True       NaN
# 56       395093253.31204       444439623.31204            False       NaN
# 57 589270406494833.50000 589519077523462.00000            False       NaN
# 58      1478809897.43149      1478809897.43149             True       NaN
# 59        19744459.37500        19744459.37500            False       NaN
# 60        19737540.00000        19737540.00000            False       NaN
# 61       120263205.46332       120263205.46332             True       NaN
# 62    115404652458.26874    117068077122.62410             True       NaN
# 63       145936688.72438       145936688.72438            False       NaN
# 64       466338618.33670       581795745.95608             True       NaN
# 65     34440578403.00486     34440578403.00486            False       NaN
# 66     56104361423.00000     99987365591.00000            False       NaN
# 67      2518346354.11617      5110221387.05400             True       NaN
# 68    145461176383.70526    145461176383.70526             True       NaN
# 69     35925585512.10200     37116609473.74700            False       NaN
# 70     86993835819.56819     86993913900.11557             True       NaN
# 52                      2.49060                      0.09442
# 53                    -14.84260                     -0.53749
# 54                     -3.38420                     -0.99516
# 55                     -6.82440                     -0.22723
# 56                     18.81970                     -0.87940
# 57                      2.48350                     -1.30316
# 58                    -13.44530                     -0.70912
# 59                     47.71790                     -0.93990
# 60                      9.86200                     -0.67507
# 61                     -0.45200                     -0.98603
# 62                      1.23850                      0.02339
# 63                     -3.77530                     -0.43408
# 64                    -12.60240                     -0.61940
# 65                     -4.69120                      0.05562
# 66                    -50.25690                     -0.57584
# 67                      2.34700                      0.27267
# 68                    -14.67400                     -0.57883
# 69                     -3.38420                     -0.74462
# 70                     -6.82440                     -0.17279
# 71                     18.86540                     -0.54996
# 72                      2.72140                     -1.04301
# 73                    -13.27600                     -0.50931
# 74                     47.71790                     -0.59740
# 75                      9.85920                     -0.47330
# 76                     -0.20140                     -1.40072
# 77                      1.37120                     -0.02238
# 78                     -3.64720                     -0.48698
# 79                    -12.47240                     -0.72650
# 80                     -4.64490                     -0.02683
# 81                    -50.27930                     -0.57894
# 82                      1.93400                      0.24451
# 83                    -14.63980                     -0.60729
# 84                     -2.90370                     -0.76897
# 85                     -7.18220                     -0.15057
# 86                     19.11320                     -0.60306
# 87                      2.75890                     -1.09746
# 88                    -13.25320                     -0.53370
# 89                     48.04200                     -0.62170
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                        4.97776                     -6.32739
# 1                        8.06513                    -16.43200
# 2                        0.00562                      0.11996
# 3                        3.08076                    -11.72981
# 4                        1.52297                     -4.81940
# 5                        0.00784                      0.02005
# 6                       -4.54339                      2.11463
# 7                        5.97211                     -1.71971
# 8                        4.08533                    -11.05058
# 9                        2.49632                    -10.80659
# 10                       0.67717                     -0.32066
# 11                       4.87452                    -13.77828
# 12                       4.54141                    -10.11613
# 13                       1.97806                     -9.12377
# 14                       5.86700                    -15.29199
# 15                       5.26214                     -6.10244
# 16                       8.08027                    -16.36639
# 17                       0.01549                      0.12805
# 18                       3.21511                    -11.58693
# 19                       1.44976                     -4.67862
# 20                      -0.00137                      0.00583
# 21                      -4.01955                      2.59131
# 22                       6.15650                     -1.63640
# 23                       4.32266                    -10.84929
# 24                       2.53281                    -10.87824
# 25                       0.69033                     -0.25242
# 26                       5.02609                    -13.59613
# 27                       4.57591                    -10.02616
# 28                       2.02624                     -9.13407
# 29                       6.01618                    -15.27659
# 30                       5.50418                     -5.91601
# 31                       8.07395                    -16.30540
# 32                      -0.03633                      0.09429
# 33                       3.25044                    -11.55687
# 34                       1.56000                     -4.61560
# 35                      -0.01662                     -0.01242
# 36                      -4.03720                      2.59474
# 37                       6.09874                     -1.64332
# 38                       4.31710                    -10.82508
# 39                       2.59206                    -10.83935
# 40                       0.68711                     -0.25616
# 41                       5.09576                    -13.53125
# 42                       4.62034                     -9.97937
# 43                       2.08904                     -9.10290
# 44                       6.04529                    -15.28625
# 45                       5.50418                     -5.91601
# 46                       8.24639                    -16.18095
# 47                       0.06088                      0.13459
# 48                       3.24544                    -11.54897
# 49                       1.57325                     -4.59437
# 50                       0.00915                     -0.01842
# 51                      -3.91758                      2.84309
ote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          -0.62373                       5.35284
# Ethereum                         -1.29956                       8.14122
# Tether USDt                       0.00661                       0.01726
# BNB                              -0.68294                       3.28084
# Solana                           -0.98653                       1.69815
# USDC                             -0.00308                       0.00905
# XRP                              -0.81726                      -4.07846
# Toncoin                           0.10688                       6.05276
# Dogecoin                         -0.77912                       4.42548
# Cardano                          -0.96632                       2.65768
# TRON                             -0.21174                       0.71574
# Avalanche                        -0.83740                       5.11469
# Shiba Inu                        -1.28662                       4.72228
# Polkadot                         -0.67574                       2.17034
# Bitcoin Cash                     -0.88670                       6.12162
#
#               quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                          -6.03817                       3.44876
# Ethereum                        -16.30021                     -14.81596
# Tether USDt                       0.11825                       0.05228
# BNB                             -11.52818                      -3.75834
# Solana                           -4.53817                       9.11899
# USDC                              0.00494                       0.01414
# XRP                               2.62686                      33.45470
# Toncoin                          -1.61976                     -11.48953
# Dogecoin                        -10.72434                      -3.94212
# Cardano                         -10.73802                     -10.85581
# TRON                             -0.23601                      -2.54542
# Avalanche                       -13.42372                     -19.46419
# Shiba Inu                        -9.91773                     -16.04285
# Polkadot                         -9.05040                     -22.29104
# Bitcoin Cash                    -15.17361                       0.99959
#
#               quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                          -12.62638                      -0.36736
# Ethereum                         -28.16594                      -9.24194
# Tether USDt                        0.07169                       0.08109
# BNB                              -21.58810                     -13.85221
# Solana                            -1.94405                       8.32789
# USDC                               0.00507                       0.01398
# XRP                               18.62692                      17.16938
# Toncoin                           -8.34107                      -3.05835
# Dogecoin                         -28.05103                     -27.23237
# Cardano                          -23.66720                     -22.90173
# TRON                               9.02777                      -0.03059
# Avalanche                        -33.93159                     -35.31247
# Shiba Inu                        -39.95126                     -38.13947
# Polkadot                         -26.47219                     -28.50853
# Bitcoin Cash                     -26.15656                     -19.67840

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin       quote.USD.percent_change_1h     -0.62373
#               quote.USD.percent_change_24h     5.35284
#               quote.USD.percent_change_7d     -6.03817
#               quote.USD.percent_change_30d     3.44876
#               quote.USD.percent_change_60d   -12.62638
#               quote.USD.percent_change_90d    -0.36736
# Ethereum      quote.USD.percent_change_1h     -1.29956
#               quote.USD.percent_change_24h     8.14122
#               quote.USD.percent_change_7d    -16.30021
#               quote.USD.percent_change_30d   -14.81596
#               quote.USD.percent_change_60d   -28.16594
#               quote.USD.percent_change_90d    -9.24194
# Tether USDt   quote.USD.percent_change_1h      0.00661
#               quote.USD.percent_change_24h     0.01726
#               quote.USD.percent_change_7d      0.11825
#               quote.USD.percent_change_30d     0.05228
#               quote.USD.percent_change_60d     0.07169
#               quote.USD.percent_change_90d     0.08109
# BNB           quote.USD.percent_change_1h     -0.68294
#               quote.USD.percent_change_24h     3.28084
#               quote.USD.percent_change_7d    -11.52818
#               quote.USD.percent_change_30d    -3.75834
#               quote.USD.percent_change_60d   -21.58810
#               quote.USD.percent_change_90d   -13.85221
# Solana        quote.USD.percent_change_1h     -0.98653
#               quote.USD.percent_change_24h     1.69815
#               quote.USD.percent_change_7d     -4.53817
#               quote.USD.percent_change_30d     9.11899
#               quote.USD.percent_change_60d    -1.94405
#               quote.USD.percent_change_90d     8.32789
# USDC          quote.USD.percent_change_1h     -0.00308
#               quote.USD.percent_change_24h     0.00905
#               quote.USD.percent_change_7d      0.00494
#               quote.USD.percent_change_30d     0.01414
#               quote.USD.percent_change_60d     0.00507
#               quote.USD.percent_change_90d     0.01398
# XRP           quote.USD.percent_change_1h     -0.81726
#               quote.USD.percent_change_24h    -4.07846
#               quote.USD.percent_change_7d      2.62686
#               quote.USD.percent_change_30d    33.45470
#               quote.USD.percent_change_60d    18.62692
#               quote.USD.percent_change_90d    17.16938
# Toncoin       quote.USD.percent_change_1h      0.10688
#               quote.USD.percent_change_24h     6.05276
#               quote.USD.percent_change_7d     -1.61976
#               quote.USD.percent_change_30d   -11.48953
#               quote.USD.percent_change_60d    -8.34107
#               quote.USD.percent_change_90d    -3.05835
# Dogecoin      quote.USD.percent_change_1h     -0.77912
#               quote.USD.percent_change_24h     4.42548
#               quote.USD.percent_change_7d    -10.72434
#               quote.USD.percent_change_30d    -3.94212
#               quote.USD.percent_change_60d   -28.05103
#               quote.USD.percent_change_90d   -27.23237
# Cardano       quote.USD.percent_change_1h     -0.96632
#               quote.USD.percent_change_24h     2.65768
#               quote.USD.percent_change_7d    -10.73802
#               quote.USD.percent_change_30d   -10.85581
#               quote.USD.percent_change_60d   -23.66720
#               quote.USD.percent_change_90d   -22.90173
# TRON          quote.USD.percent_change_1h     -0.21174
#               quote.USD.percent_change_24h     0.71574
#               quote.USD.percent_change_7d     -0.23601
#               quote.USD.percent_change_30d    -2.54542
#               quote.USD.percent_change_60d     9.02777
#               quote.USD.percent_change_90d    -0.03059
# Avalanche     quote.USD.percent_change_1h     -0.83740
#               quote.USD.percent_change_24h     5.11469
#               quote.USD.percent_change_7d    -13.42372
#               quote.USD.percent_change_30d   -19.46419
#               quote.USD.percent_change_60d   -33.93159
#               quote.USD.percent_change_90d   -35.31247
# Shiba Inu     quote.USD.percent_change_1h     -1.28662
#               quote.USD.percent_change_24h     4.72228
#               quote.USD.percent_change_7d     -9.91773
#               quote.USD.percent_change_30d   -16.04285
#               quote.USD.percent_change_60d   -39.95126
#               quote.USD.percent_change_90d   -38.13947
# Polkadot      quote.USD.percent_change_1h     -0.67574
#               quote.USD.percent_change_24h     2.17034
#               quote.USD.percent_change_7d     -9.05040
#               quote.USD.percent_change_30d   -22.29104
#               quote.USD.percent_change_60d   -26.47219
#               quote.USD.percent_change_90d   -28.50853
# Bitcoin Cash  quote.USD.percent_change_1h     -0.88670
#               quote.USD.percent_change_24h     6.12162
#               quote.USD.percent_change_7d    -15.17361
#               quote.USD.percent_change_30d     0.99959
#               quote.USD.percent_change_60d   -26.15656
#               quote.USD.percent_change_90d   -19.67840
# dtype: float64

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                              values
# name
# Bitcoin      quote.USD.percent_change_1h   -0.62373
#              quote.USD.percent_change_24h   5.35284
#              quote.USD.percent_change_7d   -6.03817
#              quote.USD.percent_change_30d   3.44876
#              quote.USD.percent_change_60d -12.62638
#              quote.USD.percent_change_90d  -0.36736
# Ethereum     quote.USD.percent_change_1h   -1.29956
#              quote.USD.percent_change_24h   8.14122
#              quote.USD.percent_change_7d  -16.30021
#              quote.USD.percent_change_30d -14.81596
#              quote.USD.percent_change_60d -28.16594
#              quote.USD.percent_change_90d  -9.24194
# Tether USDt  quote.USD.percent_change_1h    0.00661
#              quote.USD.percent_change_24h   0.01726
#              quote.USD.percent_change_7d    0.11825
#              quote.USD.percent_change_30d   0.05228
#              quote.USD.percent_change_60d   0.07169
#              quote.USD.percent_change_90d   0.08109
# BNB          quote.USD.percent_change_1h   -0.68294
#              quote.USD.percent_change_24h   3.28084
#              quote.USD.percent_change_7d  -11.52818
#              quote.USD.percent_change_30d  -3.75834
#              quote.USD.percent_change_60d -21.58810
#              quote.USD.percent_change_90d -13.85221
# Solana       quote.USD.percent_change_1h   -0.98653
#              quote.USD.percent_change_24h   1.69815
#              quote.USD.percent_change_7d   -4.53817
#              quote.USD.percent_change_30d   9.11899
#              quote.USD.percent_change_60d  -1.94405
#              quote.USD.percent_change_90d   8.32789
# USDC         quote.USD.percent_change_1h   -0.00308
#              quote.USD.percent_change_24h   0.00905
#              quote.USD.percent_change_7d    0.00494
#              quote.USD.percent_change_30d   0.01414
#              quote.USD.percent_change_60d   0.00507
#              quote.USD.percent_change_90d   0.01398
# XRP          quote.USD.percent_change_1h   -0.81726
#              quote.USD.percent_change_24h  -4.07846
#              quote.USD.percent_change_7d    2.62686
#              quote.USD.percent_change_30d  33.45470
#              quote.USD.percent_change_60d  18.62692
#              quote.USD.percent_change_90d  17.16938
# Toncoin      quote.USD.percent_change_1h    0.10688
#              quote.USD.percent_change_24h   6.05276
#              quote.USD.percent_change_7d   -1.61976
#              quote.USD.percent_change_30d -11.48953
#              quote.USD.percent_change_60d  -8.34107
#              quote.USD.percent_change_90d  -3.05835
# Dogecoin     quote.USD.percent_change_1h   -0.77912
#              quote.USD.percent_change_24h   4.42548
#              quote.USD.percent_change_7d  -10.72434
#              quote.USD.percent_change_30d  -3.94212
#              quote.USD.percent_change_60d -28.05103
#              quote.USD.percent_change_90d -27.23237
# Cardano      quote.USD.percent_change_1h   -0.96632
#              quote.USD.percent_change_24h   2.65768
#              quote.USD.percent_change_7d  -10.73802
#              quote.USD.percent_change_30d -10.85581
#              quote.USD.percent_change_60d -23.66720
#              quote.USD.percent_change_90d -22.90173
# TRON         quote.USD.percent_change_1h   -0.21174
#              quote.USD.percent_change_24h   0.71574
#              quote.USD.percent_change_7d   -0.23601
#              quote.USD.percent_change_30d  -2.54542
#              quote.USD.percent_change_60d   9.02777
#              quote.USD.percent_change_90d  -0.03059
# Avalanche    quote.USD.percent_change_1h   -0.83740
#              quote.USD.percent_change_24h   5.11469
#              quote.USD.percent_change_7d  -13.42372
#              quote.USD.percent_change_30d -19.46419
#              quote.USD.percent_change_60d -33.93159
#              quote.USD.percent_change_90d -35.31247
# Shiba Inu    quote.USD.percent_change_1h   -1.28662
#              quote.USD.percent_change_24h   4.72228
#              quote.USD.percent_change_7d   -9.91773
#              quote.USD.percent_change_30d -16.04285
#              quote.USD.percent_change_60d -39.95126
#              quote.USD.percent_change_90d -38.13947
# Polkadot     quote.USD.percent_change_1h   -0.67574
#              quote.USD.percent_change_24h   2.17034
#              quote.USD.percent_change_7d   -9.05040
#              quote.USD.percent_change_30d -22.29104
#              quote.USD.percent_change_60d -26.47219
#              quote.USD.percent_change_90d -28.50853
# Bitcoin Cash quote.USD.percent_change_1h   -0.88670
#              quote.USD.percent_change_24h   6.12162
#              quote.USD.percent_change_7d  -15.17361
#              quote.USD.percent_change_30d   0.99959
#              quote.USD.percent_change_60d -26.15656
#              quote.USD.percent_change_90d -19.67840

# %%
index = pd.Index(range(90))
df6 = df5.reset_index()
df6
# Out:
#             name                       level_1    values
# 0        Bitcoin   quote.USD.percent_change_1h  -0.62373
# 1        Bitcoin  quote.USD.percent_change_24h   5.35284
# 2        Bitcoin   quote.USD.percent_change_7d  -6.03817
# 3        Bitcoin  quote.USD.percent_change_30d   3.44876
# 4        Bitcoin  quote.USD.percent_change_60d -12.62638
# 5        Bitcoin  quote.USD.percent_change_90d  -0.36736
# 6       Ethereum   quote.USD.percent_change_1h  -1.29956
# 7       Ethereum  quote.USD.percent_change_24h   8.14122
# 8       Ethereum   quote.USD.percent_change_7d -16.30021
# 9       Ethereum  quote.USD.percent_change_30d -14.81596
# 10      Ethereum  quote.USD.percent_change_60d -28.16594
# 11      Ethereum  quote.USD.percent_change_90d  -9.24194
# 12   Tether USDt   quote.USD.percent_change_1h   0.00661
# 13   Tether USDt  quote.USD.percent_change_24h   0.01726
# 14   Tether USDt   quote.USD.percent_change_7d   0.11825
# 15   Tether USDt  quote.USD.percent_change_30d   0.05228
# 16   Tether USDt  quote.USD.percent_change_60d   0.07169
# 17   Tether USDt  quote.USD.percent_change_90d   0.08109
# 18           BNB   quote.USD.percent_change_1h  -0.68294
# 19           BNB  quote.USD.percent_change_24h   3.28084
# 20           BNB   quote.USD.percent_change_7d -11.52818
# 21           BNB  quote.USD.percent_change_30d  -3.75834
# 22           BNB  quote.USD.percent_change_60d -21.58810
# 23           BNB  quote.USD.percent_change_90d -13.85221
# 24        Solana   quote.USD.percent_change_1h  -0.98653
# 25        Solana  quote.USD.percent_change_24h   1.69815
# 26        Solana   quote.USD.percent_change_7d  -4.53817
# 27        Solana  quote.USD.percent_change_30d   9.11899
# 28        Solana  quote.USD.percent_change_60d  -1.94405
# 29        Solana  quote.USD.percent_change_90d   8.32789
# 30          USDC   quote.USD.percent_change_1h  -0.00308
# 31          USDC  quote.USD.percent_change_24h   0.00905
# 32          USDC   quote.USD.percent_change_7d   0.00494
# 33          USDC  quote.USD.percent_change_30d   0.01414
# 34          USDC  quote.USD.percent_change_60d   0.00507
# 35          USDC  quote.USD.percent_change_90d   0.01398
# 36           XRP   quote.USD.percent_change_1h  -0.81726
# 37           XRP  quote.USD.percent_change_24h  -4.07846
# 38           XRP   quote.USD.percent_change_7d   2.62686
# 39           XRP  quote.USD.percent_change_30d  33.45470
# 40           XRP  quote.USD.percent_change_60d  18.62692
# 41           XRP  quote.USD.percent_change_90d  17.16938
# 42       Toncoin   quote.USD.percent_change_1h   0.10688
# 43       Toncoin  quote.USD.percent_change_24h   6.05276
# 44       Toncoin   quote.USD.percent_change_7d  -1.61976
# 45       Toncoin  quote.USD.percent_change_30d -11.48953
# 46       Toncoin  quote.USD.percent_change_60d  -8.34107
# 47       Toncoin  quote.USD.percent_change_90d  -3.05835
# 48      Dogecoin   quote.USD.percent_change_1h  -0.77912
# 49      Dogecoin  quote.USD.percent_change_24h   4.42548
# 50      Dogecoin   quote.USD.percent_change_7d -10.72434
# 51      Dogecoin  quote.USD.percent_change_30d  -3.94212
# 52      Dogecoin  quote.USD.percent_change_60d -28.05103
# 53      Dogecoin  quote.USD.percent_change_90d -27.23237
# 54       Cardano   quote.USD.percent_change_1h  -0.96632
# 55       Cardano  quote.USD.percent_change_24h   2.65768
# 56       Cardano   quote.USD.percent_change_7d -10.73802
# 57       Cardano  quote.USD.percent_change_30d -10.85581
# 58       Cardano  quote.USD.percent_change_60d -23.66720
# 59       Cardano  quote.USD.percent_change_90d -22.90173
# 60          TRON   quote.USD.percent_change_1h  -0.21174
# 61          TRON  quote.USD.percent_change_24h   0.71574
# 62          TRON   quote.USD.percent_change_7d  -0.23601
# 63          TRON  quote.USD.percent_change_30d  -2.54542
# 64          TRON  quote.USD.percent_change_60d   9.02777
# 65          TRON  quote.USD.percent_change_90d  -0.03059
# 66     Avalanche   quote.USD.percent_change_1h  -0.83740
# 67     Avalanche  quote.USD.percent_change_24h   5.11469
# 68     Avalanche   quote.USD.percent_change_7d -13.42372
# 69     Avalanche  quote.USD.percent_change_30d -19.46419
# 70     Avalanche  quote.USD.percent_change_60d -33.93159
# 71     Avalanche  quote.USD.percent_change_90d -35.31247
# 72     Shiba Inu   quote.USD.percent_change_1h  -1.28662
# 73     Shiba Inu  quote.USD.percent_change_24h   4.72228
# 74     Shiba Inu   quote.USD.percent_change_7d  -9.91773
# 75     Shiba Inu  quote.USD.percent_change_30d -16.04285
# 76     Shiba Inu  quote.USD.percent_change_60d -39.95126
# 77     Shiba Inu  quote.USD.percent_change_90d -38.13947
# 78      Polkadot   quote.USD.percent_change_1h  -0.67574
# 79      Polkadot  quote.USD.percent_change_24h   2.17034
# 80      Polkadot   quote.USD.percent_change_7d  -9.05040
# 81      Polkadot  quote.USD.percent_change_30d -22.29104
# 82      Polkadot  quote.USD.percent_change_60d -26.47219
# 83      Polkadot  quote.USD.percent_change_90d -28.50853
# 84  Bitcoin Cash   quote.USD.percent_change_1h  -0.88670
# 85  Bitcoin Cash  quote.USD.percent_change_24h   6.12162
# 86  Bitcoin Cash   quote.USD.percent_change_7d -15.17361
# 87  Bitcoin Cash  quote.USD.percent_change_30d   0.99959
# 88  Bitcoin Cash  quote.USD.percent_change_60d -26.15656
# 89  Bitcoin Cash  quote.USD.percent_change_90d -19.67840

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#             name                percent_change    values
# 0        Bitcoin   quote.USD.percent_change_1h  -0.62373
# 1        Bitcoin  quote.USD.percent_change_24h   5.35284
# 2        Bitcoin   quote.USD.percent_change_7d  -6.03817
# 3        Bitcoin  quote.USD.percent_change_30d   3.44876
# 4        Bitcoin  quote.USD.percent_change_60d -12.62638
# 5        Bitcoin  quote.USD.percent_change_90d  -0.36736
# 6       Ethereum   quote.USD.percent_change_1h  -1.29956
# 7       Ethereum  quote.USD.percent_change_24h   8.14122
# 8       Ethereum   quote.USD.percent_change_7d -16.30021
# 9       Ethereum  quote.USD.percent_change_30d -14.81596
# 10      Ethereum  quote.USD.percent_change_60d -28.16594
# 11      Ethereum  quote.USD.percent_change_90d  -9.24194
# 12   Tether USDt   quote.USD.percent_change_1h   0.00661
# 13   Tether USDt  quote.USD.percent_change_24h   0.01726
# 14   Tether USDt   quote.USD.percent_change_7d   0.11825
# 15   Tether USDt  quote.USD.percent_change_30d   0.05228
# 16   Tether USDt  quote.USD.percent_change_60d   0.07169
# 17   Tether USDt  quote.USD.percent_change_90d   0.08109
# 18           BNB   quote.USD.percent_change_1h  -0.68294
# 19           BNB  quote.USD.percent_change_24h   3.28084
# 20           BNB   quote.USD.percent_change_7d -11.52818
# 21           BNB  quote.USD.percent_change_30d  -3.75834
# 22           BNB  quote.USD.percent_change_60d -21.58810
# 23           BNB  quote.USD.percent_change_90d -13.85221
# 24        Solana   quote.USD.percent_change_1h  -0.98653
# 25        Solana  quote.USD.percent_change_24h   1.69815
# 26        Solana   quote.USD.percent_change_7d  -4.53817
# 27        Solana  quote.USD.percent_change_30d   9.11899
# 28        Solana  quote.USD.percent_change_60d  -1.94405
# 29        Solana  quote.USD.percent_change_90d   8.32789
# 30          USDC   quote.USD.percent_change_1h  -0.00308
# 31          USDC  quote.USD.percent_change_24h   0.00905
# 32          USDC   quote.USD.percent_change_7d   0.00494
# 33          USDC  quote.USD.percent_change_30d   0.01414
# 34          USDC  quote.USD.percent_change_60d   0.00507
# 35          USDC  quote.USD.percent_change_90d   0.01398
# 36           XRP   quote.USD.percent_change_1h  -0.81726
# 37           XRP  quote.USD.percent_change_24h  -4.07846
# 38           XRP   quote.USD.percent_change_7d   2.62686
# 39           XRP  quote.USD.percent_change_30d  33.45470
# 40           XRP  quote.USD.percent_change_60d  18.62692
# 41           XRP  quote.USD.percent_change_90d  17.16938
# 42       Toncoin   quote.USD.percent_change_1h   0.10688
# 43       Toncoin  quote.USD.percent_change_24h   6.05276
# 44       Toncoin   quote.USD.percent_change_7d  -1.61976
# 45       Toncoin  quote.USD.percent_change_30d -11.48953
# 46       Toncoin  quote.USD.percent_change_60d  -8.34107
# 47       Toncoin  quote.USD.percent_change_90d  -3.05835
# 48      Dogecoin   quote.USD.percent_change_1h  -0.77912
# 49      Dogecoin  quote.USD.percent_change_24h   4.42548
# 50      Dogecoin   quote.USD.percent_change_7d -10.72434
# 51      Dogecoin  quote.USD.percent_change_30d  -3.94212
# 52      Dogecoin  quote.USD.percent_change_60d -28.05103
# 53      Dogecoin  quote.USD.percent_change_90d -27.23237
# 54       Cardano   quote.USD.percent_change_1h  -0.96632
# 55       Cardano  quote.USD.percent_change_24h   2.65768
# 56       Cardano   quote.USD.percent_change_7d -10.73802
# 57       Cardano  quote.USD.percent_change_30d -10.85581
# 58       Cardano  quote.USD.percent_change_60d -23.66720
# 59       Cardano  quote.USD.percent_change_90d -22.90173
# 60          TRON   quote.USD.percent_change_1h  -0.21174
# 61          TRON  quote.USD.percent_change_24h   0.71574
# 62          TRON   quote.USD.percent_change_7d  -0.23601
# 63          TRON  quote.USD.percent_change_30d  -2.54542
# 64          TRON  quote.USD.percent_change_60d   9.02777
# 65          TRON  quote.USD.percent_change_90d  -0.03059
# 66     Avalanche   quote.USD.percent_change_1h  -0.83740
# 67     Avalanche  quote.USD.percent_change_24h   5.11469
# 68     Avalanche   quote.USD.percent_change_7d -13.42372
# 69     Avalanche  quote.USD.percent_change_30d -19.46419
# 70     Avalanche  quote.USD.percent_change_60d -33.93159
# 71     Avalanche  quote.USD.percent_change_90d -35.31247
# 72     Shiba Inu   quote.USD.percent_change_1h  -1.28662
# 73     Shiba Inu  quote.USD.percent_change_24h   4.72228
# 74     Shiba Inu   quote.USD.percent_change_7d  -9.91773
# 75     Shiba Inu  quote.USD.percent_change_30d -16.04285
# 76     Shiba Inu  quote.USD.percent_change_60d -39.95126
# 77     Shiba Inu  quote.USD.percent_change_90d -38.13947
# 78      Polkadot   quote.USD.percent_change_1h  -0.67574
# 79      Polkadot  quote.USD.percent_change_24h   2.17034
# 80      Polkadot   quote.USD.percent_change_7d  -9.05040
# 81      Polkadot  quote.USD.percent_change_30d -22.29104
# 82      Polkadot  quote.USD.percent_change_60d -26.47219
# 83      Polkadot  quote.USD.percent_change_90d -28.50853
# 84  Bitcoin Cash   quote.USD.percent_change_1h  -0.88670
# 85  Bitcoin Cash  quote.USD.percent_change_24h   6.12162
# 86  Bitcoin Cash   quote.USD.percent_change_7d -15.17361
# 87  Bitcoin Cash  quote.USD.percent_change_30d   0.99959
# 88  Bitcoin Cash  quote.USD.percent_change_60d -26.15656
# 89  Bitcoin Cash  quote.USD.percent_change_90d -19.67840

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h', '24h', '7d', '30d', '60d', '90d'])
df7
# Out:
#             name percent_change    values
# 0        Bitcoin             1h  -0.62373
# 1        Bitcoin            24h   5.35284
# 2        Bitcoin             7d  -6.03817
# 3        Bitcoin            30d   3.44876
# 4        Bitcoin            60d -12.62638
# 5        Bitcoin            90d  -0.36736
# 6       Ethereum             1h  -1.29956
# 7       Ethereum            24h   8.14122
# 8       Ethereum             7d -16.30021
# 9       Ethereum            30d -14.81596
# 10      Ethereum            60d -28.16594
# 11      Ethereum            90d  -9.24194
# 12   Tether USDt             1h   0.00661
# 13   Tether USDt            24h   0.01726
# 14   Tether USDt             7d   0.11825
# 15   Tether USDt            30d   0.05228
# 16   Tether USDt            60d   0.07169
# 17   Tether USDt            90d   0.08109
# 18           BNB             1h  -0.68294
# 19           BNB            24h   3.28084
# 20           BNB             7d -11.52818
# 21           BNB            30d  -3.75834
# 22           BNB            60d -21.58810
# 23           BNB            90d -13.85221
# 24        Solana             1h  -0.98653
# 25        Solana            24h   1.69815
# 26        Solana             7d  -4.53817
# 27        Solana            30d   9.11899
# 28        Solana            60d  -1.94405
# 29        Solana            90d   8.32789
# 30          USDC             1h  -0.00308
# 31          USDC            24h   0.00905
# 32          USDC             7d   0.00494
# 33          USDC            30d   0.01414
# 34          USDC            60d   0.00507
# 35          USDC            90d   0.01398
# 36           XRP             1h  -0.81726
# 37           XRP            24h  -4.07846
# 38           XRP             7d   2.62686
# 39           XRP            30d  33.45470
# 40           XRP            60d  18.62692
# 41           XRP            90d  17.16938
# 42       Toncoin             1h   0.10688
# 43       Toncoin            24h   6.05276
# 44       Toncoin             7d  -1.61976
# 45       Toncoin            30d -11.48953
# 46       Toncoin            60d  -8.34107
# 47       Toncoin            90d  -3.05835
# 48      Dogecoin             1h  -0.77912
# 49      Dogecoin            24h   4.42548
# 50      Dogecoin             7d -10.72434
# 51      Dogecoin            30d  -3.94212
# 52      Dogecoin            60d -28.05103
# 53      Dogecoin            90d -27.23237
# 54       Cardano             1h  -0.96632
# 55       Cardano            24h   2.65768
# 56       Cardano             7d -10.73802
# 57       Cardano            30d -10.85581
# 58       Cardano            60d -23.66720
# 59       Cardano            90d -22.90173
# 60          TRON             1h  -0.21174
# 61          TRON            24h   0.71574
# 62          TRON             7d  -0.23601
# 63          TRON            30d  -2.54542
# 64          TRON            60d   9.02777
# 65          TRON            90d  -0.03059
# 66     Avalanche             1h  -0.83740
# 67     Avalanche            24h   5.11469
# 68     Avalanche             7d -13.42372
# 69     Avalanche            30d -19.46419
# 70     Avalanche            60d -33.93159
# 71     Avalanche            90d -35.31247
# 72     Shiba Inu             1h  -1.28662
# 73     Shiba Inu            24h   4.72228
# 74     Shiba Inu             7d  -9.91773
# 75     Shiba Inu            30d -16.04285
# 76     Shiba Inu            60d -39.95126
# 77     Shiba Inu            90d -38.13947
# 78      Polkadot             1h  -0.67574
# 79      Polkadot            24h   2.17034
# 80      Polkadot             7d  -9.05040
# 81      Polkadot            30d -22.29104
# 82      Polkadot            60d -26.47219
# 83      Polkadot            90d -28.50853
# 84  Bitcoin Cash             1h  -0.88670
# 85  Bitcoin Cash            24h   6.12162
# 86  Bitcoin Cash             7d -15.17361
# 87  Bitcoin Cash            30d   0.99959
# 88  Bitcoin Cash            60d -26.15656
# 89  Bitcoin Cash            90d -19.67840

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns. catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')

# %%
df9 = df[['name','quote.USD.price','timestamp']]
df9 = df9.query("name=='Ethereum'")
df9
# Out:
#         name  quote.USD.price                  timestamp
# 1   Ethereum       2632.40070 2024-08-09 11:28:40.402557
# 16  Ethereum       2636.38582 2024-08-09 11:29:41.427708
# 31  Ethereum       2637.56212 2024-08-09 11:30:42.602288
# 46  Ethereum       2641.01248 2024-08-09 11:31:43.758917
# 61  Ethereum       2642.14614 2024-08-09 11:32:44.723688
# 76  Ethereum       2633.54740 2024-08-09 11:33:45.725498

# %%
sns.set_theme(style="darkgrid")
sns.lineplot(x='timestamp', y='quote.USD.price', data=df9)
# Out:
# <Axes: xlabel='timestamp', ylabel='quote.USD.price'>
